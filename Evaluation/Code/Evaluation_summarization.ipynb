# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Simple Retrieval

# %%
copyright = pd.read_excel("/content/df_copyright_simple.xlsx")
divorce = pd.read_excel("/content/df_divorce_simple.xlsx")
cp = pd.read_excel("/content/df_cp_simple.xlsx")
inheritance = pd.read_excel("/content/df_inheritance_simple.xlsx")

# %%
copyright.head()
# Out:
#                                                Query  \
# 0  What is the primary purpose of copyright, acco...
# 1  What is the form that needs to be filled out t...
# 2  What is the typical duration of copyright prot...
# 3  What is the minimum punishment for copyright i...
# 4  What is the minimum rank of a police officer w...
#
#                                              Context  \
# 0  It is a bundle of rights comprising of rights ...
# 1  To apply for copyright, application for regist...
# 2  Copyright protection typically lasts for 60 ye...
# 3  Remedy for copyright infringement\r\nCopyright...
# 4  Also, in case a copyright infringement has hap...
#
#                                            Reference  \
# 0  The primary purpose of copyright is to ensure ...
# 1  Form IV needs to be filled out to apply for co...
# 2  Typical duration of copyright duration is 60 y...
# 3  The minimum punishment for infringement of a c...
# ...

# %%
print("Relevancy scores:", sum(copyright["Relevancy Score"])/len(copyright))
print("Faithfulness scores:", sum(copyright["Faithfulness Score"])/len(copyright))
# Out:
# Relevancy scores: 1.0
# Faithfulness scores: 0.6666666666666666

# %%
copyright['Semantic Similarity Score'].describe()
# Out:
# count    6.000000
# mean     0.835086
# std      0.112536
# min      0.704440
# 25%      0.740940
# 50%      0.841514
# 75%      0.909482
# max      0.983493
# Name: Semantic Similarity Score, dtype: float64

# %%
copyright['Correctness Score'].describe()
# Out:
# count    6.000000
# mean     3.833333
# std      0.408248
# min      3.000000
# 25%      4.000000
# 50%      4.000000
# 75%      4.000000
# max      4.000000
# Name: Correctness Score, dtype: float64

# %%
divorce.head()
# Out:
#                                                Query  \
# 0  What type of divorce is considered by the cour...
# 1  What is the minimum duration of separation req...
# 2  What are the three aspects that couples need t...
# 3  What types of expenses will be considered when...
# 4  What is one circumstance that may favor the sp...
#
#                                              Context  \
# 0  Divorce with Mutual Consent\r\nWhen the couple...
# 1  Section 10A of Indian Divorce Act, 1869, requi...
# 2  maintenance and property rights need to be agr...
# 3  Custody of child, alimony to wife and litigati...
# 4  the failing health or a medical condition of o...
#
#                                            Reference  \
# 0                        Divorce with Mutual consent
# 1  The minimum duration of sepration required for...
# 2  The three aspects that couples needto reach a ...
# 3  Expenses considered while issuing a decree of ...
# ...

# %%
print("Relevancy scores:", sum(divorce["Relevancy Score"])/len(divorce))
print("Faithfulness scores:", sum(divorce["Faithfulness Score"])/len(divorce))
# Out:
# Relevancy scores: 0.6
# Faithfulness scores: 0.4

# %%
divorce['Semantic Similarity Score'].describe()
# Out:
# count    5.000000
# mean     0.863961
# std      0.106279
# min      0.718859
# 25%      0.791490
# 50%      0.904862
# 75%      0.924057
# max      0.980539
# Name: Semantic Similarity Score, dtype: float64

# %%
divorce['Correctness Score'].describe()
# Out:
# count    5.000000
# mean     3.600000
# std      0.547723
# min      3.000000
# 25%      3.000000
# 50%      4.000000
# 75%      4.000000
# max      4.000000
# Name: Correctness Score, dtype: float64

# %%
cp.head()
# Out:
#                                                Query  \
# 0  What is the main law that provides protection ...
# 1  What is the primary objective of the Consumer ...
# 2  What is the procedure to file a complaint in c...
# 3  What is the possible outcome if the complainan...
# 4  What kind of goods and services does consumer ...
#
#                                              Context  \
# 0  \ufeffConsumer Protection Laws in India\r\nCon...
# 1  In this article, we look at the protection aff...
# 2  Procedure to File Consumer Case\r\nAny consume...
# 3  Hence, if during the proceedings, the complain...
# 4  The Act covers all goods and services includin...
#
#                                            Reference  \
# 0  Consumer Protection Amendement Act, 2002 is th...
# 1  The primary objective of the Consumer Protecti...
# 2  Any consumer complaint relating to a good or s...
# 3  If the complainant fails to appear on the date...
# ...

# %%
print("Relevancy scores:", sum(cp["Relevancy Score"])/len(cp))
print("Faithfulness scores:", sum(cp["Faithfulness Score"])/len(cp))
# Out:
# Relevancy scores: 1.0
# Faithfulness scores: 0.6

# %%
cp['Semantic Similarity Score'].describe()
# Out:
# count    5.000000
# mean     0.872945
# std      0.040516
# min      0.827317
# 25%      0.838335
# 50%      0.875117
# 75%      0.901145
# max      0.922810
# Name: Semantic Similarity Score, dtype: float64

# %%
cp['Correctness Score'].describe()
# Out:
# count    5.0
# mean     4.0
# std      0.0
# min      4.0
# 25%      4.0
# 50%      4.0
# 75%      4.0
# max      4.0
# Name: Correctness Score, dtype: float64

# %%
inheritance.head()
# Out:
#                                                Query  \
# 0  What is the legal document that contains speci...
# 1  What is a legal heir, according to the given d...
# 2  Who is the legal heir of a female Hindu who di...
# 3  What was the change in the right share in ance...
# 4  What is the minimum information required to ap...
#
#                                              Context  \
# 0  What is a will?\r\nUnder the Indian Succession...
# 1  Therefore a legal heir is an individual who ta...
# 2  Mother of the mother\r\n* Father of the mother...
# 3  Rights of Daughters\r\nBefore the year 2005, t...
# 4  Documents required for legal heir certificate\...
#
#                                            Reference  \
# 0  Will is the legal document that contains speci...
# 1  a legal heir is an individual who takes the pl...
# 2  The daughters and the sons, including the chil...
# 3  Before the year 2005, the right share in the a...
# ...

# %%
print("Relevancy scores:", sum(inheritance["Relevancy Score"])/len(inheritance))
print("Faithfulness scores:", sum(inheritance["Faithfulness Score"])/len(inheritance))
# Out:
# Relevancy scores: 1.0
# Faithfulness scores: 0.8

# %%
inheritance['Semantic Similarity Score'].describe()
# Out:
# count    5.000000
# mean     0.825330
# std      0.136815
# min      0.621223
# 25%      0.795928
# 50%      0.814912
# 75%      0.912004
# max      0.982581
# Name: Semantic Similarity Score, dtype: float64

# %%
inheritance['Correctness Score'].describe()
# Out:
# count    5.000000
# mean     3.800000
# std      0.447214
# min      3.000000
# 25%      4.000000
# 50%      4.000000
# 75%      4.000000
# max      4.000000
# Name: Correctness Score, dtype: float64

# %% [markdown]
# ## HyDE

# %%
copyright = pd.read_excel("/content/df_copyright_hyde.xlsx")
divorce = pd.read_excel("/content/df_divorce_hyde.xlsx")
cp = pd.read_excel("/content/df_cp_hyde.xlsx")
inheritance = pd.read_excel("/content/df_inheritance_hyde.xlsx")

# %%
copyright.head()
# Out:
#                                                Query  \
# 0  What is the primary purpose of copyright, acco...
# 1  What is the form that needs to be filled out t...
# 2  What is the typical duration of copyright prot...
# 3  What is the minimum punishment for copyright i...
# 4  What is the minimum rank of a police officer w...
#
#                                              Context  \
# 0  It is a bundle of rights comprising of rights ...
# 1  To apply for copyright, application for regist...
# 2  Copyright protection typically lasts for 60 ye...
# 3  Remedy for copyright infringement\r\nCopyright...
# 4  Also, in case a copyright infringement has hap...
#
#                                            Reference  \
# 0  The primary purpose of copyright is to ensure ...
# 1  Form IV needs to be filled out to apply for co...
# 2  Typical duration of copyright duration is 60 y...
# 3  The minimum punishment for infringement of a c...
# ...

# %%
print("Relevancy scores:", sum(copyright["Relevancy Score"])/len(copyright))
print("Faithfulness scores:", sum(copyright["Faithfulness Score"])/len(copyright))
# Out:
# Relevancy scores: 1.0
# Faithfulness scores: 0.6666666666666666

# %%
copyright['Semantic Similarity Score'].describe()
# Out:
# count    6.000000
# mean     0.831146
# std      0.109626
# min      0.704440
# 25%      0.740940
# 50%      0.838646
# 75%      0.894494
# max      0.983664
# Name: Semantic Similarity Score, dtype: float64

# %%
copyright['Correctness Score'].describe()
# Out:
# count    6.000000
# mean     3.833333
# std      0.408248
# min      3.000000
# 25%      4.000000
# 50%      4.000000
# 75%      4.000000
# max      4.000000
# Name: Correctness Score, dtype: float64

# %%
divorce.head()
# Out:
#                                                Query  \
# 0  What type of divorce is considered by the cour...
# 1  What is the minimum duration of separation req...
# 2  What are the three aspects that couples need t...
# 3  What types of expenses will be considered when...
# 4  What is one circumstance that may favor the sp...
#
#                                              Context  \
# 0  Divorce with Mutual Consent\r\nWhen the couple...
# 1  Section 10A of Indian Divorce Act, 1869, requi...
# 2  maintenance and property rights need to be agr...
# 3  Custody of child, alimony to wife and litigati...
# 4  the failing health or a medical condition of o...
#
#                                            Reference  \
# 0                        Divorce with Mutual consent
# 1  The minimum duration of sepration required for...
# 2  The three aspects that couples needto reach a ...
# 3  Expenses considered while issuing a decree of ...
# ...

# %%
print("Relevancy scores:", sum(divorce["Relevancy Score"])/len(divorce))
print("Faithfulness scores:", sum(divorce["Faithfulness Score"])/len(divorce))
# Out:
# Relevancy scores: 0.8
# Faithfulness scores: 0.4

# %%
divorce['Semantic Similarity Score'].describe()
# Out:
# count    5.000000
# mean     0.851752
# std      0.096905
# min      0.718859
# 25%      0.791490
# 50%      0.868931
# 75%      0.924057
# max      0.955422
# Name: Semantic Similarity Score, dtype: float64

# %%
divorce['Correctness Score'].describe()
# Out:
# count    5.000000
# mean     3.600000
# std      0.547723
# min      3.000000
# 25%      3.000000
# 50%      4.000000
# 75%      4.000000
# max      4.000000
# Name: Correctness Score, dtype: float64

# %%
cp.head()
# Out:
#                                                Query  \
# 0  What is the main law that provides protection ...
# 1  What is the primary objective of the Consumer ...
# 2  What is the procedure to file a complaint in c...
# 3  What is the possible outcome if the complainan...
# 4  What kind of goods and services does consumer ...
#
#                                              Context  \
# 0  \ufeffConsumer Protection Laws in India\r\nCon...
# 1  In this article, we look at the protection aff...
# 2  Procedure to File Consumer Case\r\nAny consume...
# 3  Hence, if during the proceedings, the complain...
# 4  The Act covers all goods and services includin...
#
#                                            Reference  \
# 0  Consumer Protection Amendement Act, 2002 is th...
# 1  The primary objective of the Consumer Protecti...
# 2  Any consumer complaint relating to a good or s...
# 3  If the complainant fails to appear on the date...
# ...

# %%
print("Relevancy scores:", sum(cp["Relevancy Score"])/len(cp))
print("Faithfulness scores:", sum(cp["Faithfulness Score"])/len(cp))
# Out:
# Relevancy scores: 1.0
# Faithfulness scores: 0.6

# %%
cp['Semantic Similarity Score'].describe()
# Out:
# count    5.000000
# mean     0.890070
# std      0.041682
# min      0.825472
# 25%      0.874324
# 50%      0.901145
# 75%      0.922810
# max      0.926599
# Name: Semantic Similarity Score, dtype: float64

# %%
cp['Correctness Score'].describe()
# Out:
# count    5.0
# mean     4.0
# std      0.0
# min      4.0
# 25%      4.0
# 50%      4.0
# 75%      4.0
# max      4.0
# Name: Correctness Score, dtype: float64

# %%
inheritance.head()
# Out:
#                                                Query  \
# 0  What is the legal document that contains speci...
# 1  What is a legal heir, according to the given d...
# 2  Who is the legal heir of a female Hindu who di...
# 3  What was the change in the right share in ance...
# 4  What is the minimum information required to ap...
#
#                                              Context  \
# 0  What is a will?\r\nUnder the Indian Succession...
# 1  Therefore a legal heir is an individual who ta...
# 2  Mother of the mother\r\n* Father of the mother...
# 3  Rights of Daughters\r\nBefore the year 2005, t...
# 4  Documents required for legal heir certificate\...
#
#                                            Reference  \
# 0  Will is the legal document that contains speci...
# 1  a legal heir is an individual who takes the pl...
# 2  The daughters and the sons, including the chil...
# 3  Before the year 2005, the right share in the a...
# ...

# %%
print("Relevancy scores:", sum(inheritance["Relevancy Score"])/len(inheritance))
print("Faithfulness scores:", sum(inheritance["Faithfulness Score"])/len(inheritance))
# Out:
# Relevancy scores: 1.0
# Faithfulness scores: 0.8

# %%
inheritance['Semantic Similarity Score'].describe()
# Out:
# count    5.000000
# mean     0.824402
# std      0.135492
# min      0.621223
# 25%      0.795928
# 50%      0.814912
# 75%      0.912004
# max      0.977945
# Name: Semantic Similarity Score, dtype: float64

# %%
inheritance['Correctness Score'].describe()
# Out:
# count    5.000000
# mean     3.800000
# std      0.447214
# min      3.000000
# 25%      4.000000
# 50%      4.000000
# 75%      4.000000
# max      4.000000
# Name: Correctness Score, dtype: float64

# %% [markdown]
# ## Query fusion

# %%
copyright = pd.read_excel("/content/df_copyright_fusion.xlsx")
divorce = pd.read_excel("/content/df_divorce_fusion.xlsx")
cp = pd.read_excel("/content/df_cp_fusion.xlsx")
inheritance = pd.read_excel("/content/df_inheritance_fusion.xlsx")

# %%
copyright.head()
# Out:
#                                                Query  \
# 0  What is the primary purpose of copyright, acco...
# 1  What is the form that needs to be filled out t...
# 2  What is the typical duration of copyright prot...
# 3  What is the minimum punishment for copyright i...
# 4  What is the minimum rank of a police officer w...
#
#                                              Context  \
# 0  It is a bundle of rights comprising of rights ...
# 1  To apply for copyright, application for regist...
# 2  Copyright protection typically lasts for 60 ye...
# 3  Remedy for copyright infringement\r\nCopyright...
# 4  Also, in case a copyright infringement has hap...
#
#                                            Reference  \
# 0  The primary purpose of copyright is to ensure ...
# 1  Form IV needs to be filled out to apply for co...
# 2  Typical duration of copyright duration is 60 y...
# 3  The minimum punishment for infringement of a c...
# ...

# %%
print("Relevancy scores:", sum(copyright["Relevancy Score"])/len(copyright))
print("Faithfulness scores:", sum(copyright["Faithfulness Score"])/len(copyright))
# Out:
# Relevancy scores: 1.0
# Faithfulness scores: 0.6666666666666666

# %%
copyright['Semantic Similarity Score'].describe()
# Out:
# count    6.000000
# mean     0.817351
# std      0.098830
# min      0.704440
# 25%      0.740940
# 50%      0.809026
# 75%      0.879684
# max      0.960135
# Name: Semantic Similarity Score, dtype: float64

# %%
copyright['Correctness Score'].describe()
# Out:
# count    6.000000
# mean     3.833333
# std      0.408248
# min      3.000000
# 25%      4.000000
# 50%      4.000000
# 75%      4.000000
# max      4.000000
# Name: Correctness Score, dtype: float64

# %%
divorce.head()
# Out:
#                                                Query  \
# 0  What type of divorce is considered by the cour...
# 1  What is the minimum duration of separation req...
# 2  What are the three aspects that couples need t...
# 3  What types of expenses will be considered when...
# 4  What is one circumstance that may favor the sp...
#
#                                              Context  \
# 0  Divorce with Mutual Consent\r\nWhen the couple...
# 1  Section 10A of Indian Divorce Act, 1869, requi...
# 2  maintenance and property rights need to be agr...
# 3  Custody of child, alimony to wife and litigati...
# 4  the failing health or a medical condition of o...
#
#                                            Reference  \
# 0                        Divorce with Mutual consent
# 1  The minimum duration of sepration required for...
# 2  The three aspects that couples needto reach a ...
# 3  Expenses considered while issuing a decree of ...
# ...

# %%
print("Relevancy scores:", sum(divorce["Relevancy Score"])/len(divorce))
print("Faithfulness scores:", sum(divorce["Faithfulness Score"])/len(divorce))
# Out:
# Relevancy scores: 1.0
# Faithfulness scores: 0.2

# %%
divorce['Semantic Similarity Score'].describe()
# Out:
# count    5.000000
# mean     0.856775
# std      0.104013
# min      0.718859
# 25%      0.791490
# 50%      0.868931
# 75%      0.924057
# max      0.980539
# Name: Semantic Similarity Score, dtype: float64

# %%
divorce['Correctness Score'].describe()
# Out:
# count    5.000000
# mean     3.600000
# std      0.547723
# min      3.000000
# 25%      3.000000
# 50%      4.000000
# 75%      4.000000
# max      4.000000
# Name: Correctness Score, dtype: float64

# %%
cp.head()
# Out:
#                                                Query  \
# 0  What is the main law that provides protection ...
# 1  What is the primary objective of the Consumer ...
# 2  What is the procedure to file a complaint in c...
# 3  What is the possible outcome if the complainan...
# 4  What kind of goods and services does consumer ...
#
#                                              Context  \
# 0  \ufeffConsumer Protection Laws in India\r\nCon...
# 1  In this article, we look at the protection aff...
# 2  Procedure to File Consumer Case\r\nAny consume...
# 3  Hence, if during the proceedings, the complain...
# 4  The Act covers all goods and services includin...
#
#                                            Reference  \
# 0  Consumer Protection Amendement Act, 2002 is th...
# 1  The primary objective of the Consumer Protecti...
# 2  Any consumer complaint relating to a good or s...
# 3  If the complainant fails to appear on the date...
# ...

# %%
print("Relevancy scores:", sum(cp["Relevancy Score"])/len(cp))
print("Faithfulness scores:", sum(cp["Faithfulness Score"])/len(cp))
# Out:
# Relevancy scores: 1.0
# Faithfulness scores: 0.8

# %%
cp['Semantic Similarity Score'].describe()
# Out:
# count    5.000000
# mean     0.874197
# std      0.041325
# min      0.825472
# 25%      0.838335
# 50%      0.883224
# 75%      0.901145
# max      0.922810
# Name: Semantic Similarity Score, dtype: float64

# %%
cp['Correctness Score'].describe()
# Out:
# count    5.0
# mean     4.0
# std      0.0
# min      4.0
# 25%      4.0
# 50%      4.0
# 75%      4.0
# max      4.0
# Name: Correctness Score, dtype: float64

# %%
inheritance.head()
# Out:
#                                                Query  \
# 0  What is the legal document that contains speci...
# 1  What is a legal heir, according to the given d...
# 2  Who is the legal heir of a female Hindu who di...
# 3  What was the change in the right share in ance...
# 4  What is the minimum information required to ap...
#
#                                              Context  \
# 0  What is a will?\r\nUnder the Indian Succession...
# 1  Therefore a legal heir is an individual who ta...
# 2  Mother of the mother\r\n* Father of the mother...
# 3  Rights of Daughters\r\nBefore the year 2005, t...
# 4  Documents required for legal heir certificate\...
#
#                                            Reference  \
# 0  Will is the legal document that contains speci...
# 1  a legal heir is an individual who takes the pl...
# 2  The daughters and the sons, including the chil...
# 3  Before the year 2005, the right share in the a...
# ...

# %%
print("Relevancy scores:", sum(inheritance["Relevancy Score"])/len(inheritance))
print("Faithfulness scores:", sum(inheritance["Faithfulness Score"])/len(inheritance))
# Out:
# Relevancy scores: 1.0
# Faithfulness scores: 1.0

# %%
inheritance['Semantic Similarity Score'].describe()
# Out:
# count    5.000000
# mean     0.795572
# std      0.079136
# min      0.697254
# 25%      0.757458
# 50%      0.796234
# 75%      0.814912
# max      0.912004
# Name: Semantic Similarity Score, dtype: float64

# %%
inheritance['Correctness Score'].describe()
# Out:
# count    5.000000
# mean     3.600000
# std      0.894427
# min      2.000000
# 25%      4.000000
# 50%      4.000000
# 75%      4.000000
# max      4.000000
# Name: Correctness Score, dtype: float64
